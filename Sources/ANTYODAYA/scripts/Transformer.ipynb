# %% [markdown]
# Transformation is done based on this document -- [Link](https://docs.google.com/document/d/1_wt-wO18sa5iQBy3b-WpSHDjCqRl3MeN67N1v3dTZtQ/edit#heading=h.usgit3agfa62)

# %%
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
#       2 from shapely.geometry import Point
# ----> 3 import geopandas as gpd
#       4 from geopandas import GeoDataFrame
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
# importing village shapefile from bharatmaps - 
bharat_maps_villages = gpd.read_file(r'D:\CivicDataLabs_IDS-DRR\IDS-DRR_Github\flood-data-ecosystem-Odisha\Maps\Geojson\bharatmaps_vil2017_odisha.geojson')

# %%
# %conda install geopandas
# Out:
# Channels:
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - geopandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.6.0               |  py313hca03da5_0          50 KB
#     cairo-1.16.0               |       hd886ae0_6         1.0 MB
#     cfitsio-3.470              |       h7f6438f_7         745 KB
#     folium-0.14.0              |  py313hca03da5_0         134 KB
#     fontconfig-2.14.1          |       h6402c1e_3         252 KB
#     freexl-2.0.0               |       ha3de405_0          52 KB
#     geopandas-1.0.1            |  py313hca03da5_0         1.5 MB
#     geopandas-base-1.0.1       |  py313hca03da5_0         2.2 MB
#     geotiff-1.7.0              |       hcec61be_4         126 KB
#     giflib-5.2.2               |       h80987f9_0          78 KB
#     hdf4-4.2.13                |       h5e329fb_3         700 KB
#     json-c-0.16                |       h1a28f6b_0          66 KB
#     kealib-1.5.0               |       h3444380_2         144 KB
#     libgdal-3.6.2              |      hb8790f9_10         8.3 MB
#     libkml-1.3.0               |       hc4d7c42_7         418 KB
#     libnetcdf-4.8.1            |       h7d1a7d1_5         1.1 MB
#     libspatialite-5.1.0        |       h4e90699_2         3.8 MB
#     libzip-1.8.0               |       h62fee54_1         121 KB
#     mapclassify-2.9.0          |  py313hca03da5_0         583 KB
#     minizip-4.0.3              |       ha89c15f_0          84 KB
#     nspr-4.35                  |       h313beb8_0         243 KB
#     nss-3.89.1                 |       h313beb8_0         1.8 MB
#     pixman-0.40.0              |       h1a28f6b_0         196 KB
#     poppler-24.09.0            |       hb57d120_2         1.6 MB
#     poppler-data-0.4.11        |       hca03da5_1         2.6 MB
#     proj-9.3.1                 |       hdced247_1         2.8 MB
#     pyogrio-0.10.0             |  py313hcf39714_0         782 KB
#     pyproj-3.6.1               |  py313hf165acc_1         551 KB
#     qhull-2020.2               |       h48ca7d4_2        1023 KB
#     tiledb-2.3.3               |       hb4a6b97_3         2.3 MB
#     uriparser-0.9.8            |       h2942776_0          49 KB
#     xerces-c-3.2.4             |       h313beb8_1         2.2 MB
#     ------------------------------------------------------------
#                                            Total:        37.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   branca             pkgs/main/osx-arm64::branca-0.6.0-py313hca03da5_0
#   cairo              pkgs/main/osx-arm64::cairo-1.16.0-hd886ae0_6
#   cfitsio            pkgs/main/osx-arm64::cfitsio-3.470-h7f6438f_7
#   folium             pkgs/main/osx-arm64::folium-0.14.0-py313hca03da5_0
#   fontconfig         pkgs/main/osx-arm64::fontconfig-2.14.1-h6402c1e_3
#   freexl             pkgs/main/osx-arm64::freexl-2.0.0-ha3de405_0
#   geopandas          pkgs/main/osx-arm64::geopandas-1.0.1-py313hca03da5_0
#   geopandas-base     pkgs/main/osx-arm64::geopandas-base-1.0.1-py313hca03da5_0
#   geotiff            pkgs/main/osx-arm64::geotiff-1.7.0-hcec61be_4
#   giflib             pkgs/main/osx-arm64::giflib-5.2.2-h80987f9_0
#   hdf4               pkgs/main/osx-arm64::hdf4-4.2.13-h5e329fb_3
#   json-c             pkgs/main/osx-arm64::json-c-0.16-h1a28f6b_0
#   kealib             pkgs/main/osx-arm64::kealib-1.5.0-h3444380_2
#   libgdal            pkgs/main/osx-arm64::libgdal-3.6.2-hb8790f9_10
#   libkml             pkgs/main/osx-arm64::libkml-1.3.0-hc4d7c42_7
#   libnetcdf          pkgs/main/osx-arm64::libnetcdf-4.8.1-h7d1a7d1_5
#   libspatialite      pkgs/main/osx-arm64::libspatialite-5.1.0-h4e90699_2
#   libzip             pkgs/main/osx-arm64::libzip-1.8.0-h62fee54_1
#   mapclassify        pkgs/main/osx-arm64::mapclassify-2.9.0-py313hca03da5_0
#   minizip            pkgs/main/osx-arm64::minizip-4.0.3-ha89c15f_0
#   nspr               pkgs/main/osx-arm64::nspr-4.35-h313beb8_0
#   nss                pkgs/main/osx-arm64::nss-3.89.1-h313beb8_0
#   pixman             pkgs/main/osx-arm64::pixman-0.40.0-h1a28f6b_0
#   poppler            pkgs/main/osx-arm64::poppler-24.09.0-hb57d120_2
#   poppler-data       pkgs/main/osx-arm64::poppler-data-0.4.11-hca03da5_1
#   proj               pkgs/main/osx-arm64::proj-9.3.1-hdced247_1
#   pyogrio            pkgs/main/osx-arm64::pyogrio-0.10.0-py313hcf39714_0
#   pyproj             pkgs/main/osx-arm64::pyproj-3.6.1-py313hf165acc_1
#   qhull              pkgs/main/osx-arm64::qhull-2020.2-h48ca7d4_2
#   tiledb             pkgs/main/osx-arm64::tiledb-2.3.3-hb4a6b97_3
#   uriparser          pkgs/main/osx-arm64::uriparser-0.9.8-h2942776_0
#   xerces-c           pkgs/main/osx-arm64::xerces-c-3.2.4-h313beb8_1
#
#
#
# Downloading and Extracting Packages:
# libgdal-3.6.2        | 8.3 MB    |                                       |   0%
# libspatialite-5.1.0  | 3.8 MB    |                                       |   0%
#
# proj-9.3.1           | 2.8 MB    |                                       |   0%
#
#
# poppler-data-0.4.11  | 2.6 MB    |                                       |   0%
#
#
#
# tiledb-2.3.3         | 2.3 MB    |                                       |   0%
#
#
#
#
# geopandas-base-1.0.1 | 2.2 MB    |                                       |   0%
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    |                                       |   0%
#
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    |                                       |   0%
#
#
#
#
#
#
#
# poppler-24.09.0      | 1.6 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# geopandas-1.0.1      | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1023 KB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# pyogrio-0.10.0       | 782 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cfitsio-3.470        | 745 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 700 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mapclassify-2.9.0    | 583 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 551 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libkml-1.3.0         | 418 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.1    | 252 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nspr-4.35            | 243 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 196 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kealib-1.5.0         | 144 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# poppler-data-0.4.11  | 2.6 MB    | ######                                |  16%
#
#
#
# tiledb-2.3.3         | 2.3 MB    | #########8                            |  27%
# libspatialite-5.1.0  | 3.8 MB    | ##2                                   |   6%
#
#
# poppler-data-0.4.11  | 2.6 MB    | ###############8                      |  43%
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ################################      |  87%
# libspatialite-5.1.0  | 3.8 MB    | #########6                            |  26%
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ##################################### | 100%
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ##################################### | 100%
#
#
# poppler-data-0.4.11  | 2.6 MB    | ##################################### | 100%
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | 2                                     |   1%
# libspatialite-5.1.0  | 3.8 MB    | #####################5                |  58%
#
#
# poppler-data-0.4.11  | 2.6 MB    | ##################################### | 100%
#
#
# poppler-data-0.4.11  | 2.6 MB    | ##################################### | 100%
# libspatialite-5.1.0  | 3.8 MB    | ###############################9      |  86%
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ###################1                  |  52%
# libspatialite-5.1.0  | 3.8 MB    | ##################################### | 100%
#
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | 3                                     |   1%
# libspatialite-5.1.0  | 3.8 MB    | ##################################### | 100%
#
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ####################                  |  54%
#
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# poppler-24.09.0      | 1.6 MB    | 3                                     |   1%
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ####################################5 |  99%
#
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ##################################### | 100%
#
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ##################################### | 100%
#
#
#
#
#
# libgdal-3.6.2        | 8.3 MB    |                                       |   0%
#
#
#
#
#
#
#
# poppler-24.09.0      | 1.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
#
#
# poppler-24.09.0      | 1.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# poppler-24.09.0      | 1.6 MB    | ##################################### | 100%
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ##################################### | 100%
#
#
#
#
# geopandas-base-1.0.1 | 2.2 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
# libgdal-3.6.2        | 8.3 MB    | 3                                     |   1%
#
#
#
#
# geopandas-base-1.0.1 | 2.2 MB    | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ##################################### | 100%
#
#
#
#
# libgdal-3.6.2        | 8.3 MB    | 6                                     |   2%
#
#
#
#
# libgdal-3.6.2        | 8.3 MB    | #                                     |   3%
#
# libgdal-3.6.2        | 8.3 MB    | #3                                    |   4%
#
#
#
#
# libgdal-3.6.2        | 8.3 MB    | #8                                    |   5%
#
#
#
#
# libgdal-3.6.2        | 8.3 MB    | ##3                                   |   6%
#
# libgdal-3.6.2        | 8.3 MB    | ###2                                  |   9%
#
#
#
#
# libgdal-3.6.2        | 8.3 MB    | ####2                                 |  11%
#
#
#
#
# libgdal-3.6.2        | 8.3 MB    | #####3                                |  14%
#
# libgdal-3.6.2        | 8.3 MB    | ######7                               |  18%
#
#
#
#
#
#
#
#
# geopandas-1.0.1      | 1.5 MB    | 3                                     |   1%
#
#
#
#
# libgdal-3.6.2        | 8.3 MB    | ########5                             |  23%
#
#
#
#
# libgdal-3.6.2        | 8.3 MB    | ##########8                           |  29%
#
#
#
#
# geopandas-base-1.0.1 | 2.2 MB    | #################2                    |  47%
#
#
#
#
#
#
#
#
# libgdal-3.6.2        | 8.3 MB    | #############5                        |  37%
#
# proj-9.3.1           | 2.8 MB    | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1023 KB   | 5                                     |   2%
#
#
#
#
# libgdal-3.6.2        | 8.3 MB    | #################1                    |  46%
#
#
#
#
#
#
#
#
# geopandas-1.0.1      | 1.5 MB    | ###5                                  |   9%
#
#
#
#
# libgdal-3.6.2        | 8.3 MB    | #####################7                |  59%
#
#
#
#
#
#
#
#
# geopandas-1.0.1      | 1.5 MB    | #####                                 |  14%
#
#
#
#
# libgdal-3.6.2        | 8.3 MB    | ###########################           |  73%
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1023 KB   | ##3                                   |   6%
#
# proj-9.3.1           | 2.8 MB    | ####7                                 |  13%
#
#
#
#
#
#
#
#
# geopandas-1.0.1      | 1.5 MB    | #######4                              |  20%
#
#
#
#
# libgdal-3.6.2        | 8.3 MB    | #################################8    |  91%
#
#
#
#
# libgdal-3.6.2        | 8.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# geopandas-1.0.1      | 1.5 MB    | #########3                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cfitsio-3.470        | 745 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1023 KB   | #####2                                |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cfitsio-3.470        | 745 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cfitsio-3.470        | 745 KB    | ##################################### | 100%
#
#
#
#
# geopandas-base-1.0.1 | 2.2 MB    | ##################################### | 100%
#
#
#
#
# libgdal-3.6.2        | 8.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# geopandas-1.0.1      | 1.5 MB    | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1023 KB   | #######5                              |  20%
#
# proj-9.3.1           | 2.8 MB    | #####9                                |  16%
#
#
#
#
#
#
#
#
# geopandas-1.0.1      | 1.5 MB    | #################1                    |  46%
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1023 KB   | ##########9                           |  30%
#
#
#
#
#
#
#
#
# geopandas-1.0.1      | 1.5 MB    | ######################5               |  61%
#
# proj-9.3.1           | 2.8 MB    | #######2                              |  20%
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1023 KB   | ##############4                       |  39%
#
#
#
#
#
#
#
#
# geopandas-1.0.1      | 1.5 MB    | ############################4         |  77%
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1023 KB   | ###################                   |  52%
#
#
#
#
#
#
#
#
# geopandas-1.0.1      | 1.5 MB    | ##################################### | 100%
#
# proj-9.3.1           | 2.8 MB    | #######8                              |  21%
#
#
#
#
#
#
#
#
# geopandas-1.0.1      | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# geopandas-1.0.1      | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1023 KB   | ########################3             |  66%
#
# proj-9.3.1           | 2.8 MB    | ########4                             |  23%
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1023 KB   | ###############################2      |  84%
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1023 KB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1023 KB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1023 KB   | ##################################### | 100%
#
# proj-9.3.1           | 2.8 MB    | #########                             |  25%
#
# proj-9.3.1           | 2.8 MB    | #########5                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
# pyogrio-0.10.0       | 782 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 700 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
# pyogrio-0.10.0       | 782 KB    | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 700 KB    | ###3                                  |   9%
#
# proj-9.3.1           | 2.8 MB    | #########9                            |  27%
#
#
#
#
#
#
#
#
#
#
#
#
# pyogrio-0.10.0       | 782 KB    | ######                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
# pyogrio-0.10.0       | 782 KB    | #########                             |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mapclassify-2.9.0    | 583 KB    | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 700 KB    | #####                                 |  14%
#
#
#
#
#
#
#
#
#
#
#
#
# pyogrio-0.10.0       | 782 KB    | ##############3                       |  39%
#
# proj-9.3.1           | 2.8 MB    | ##########3                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 700 KB    | ########4                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
# pyogrio-0.10.0       | 782 KB    | ##################1                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mapclassify-2.9.0    | 583 KB    | #####                                 |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 700 KB    | ############6                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 551 KB    | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# pyogrio-0.10.0       | 782 KB    | ########################9             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mapclassify-2.9.0    | 583 KB    | #########1                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 700 KB    | #################7                    |  48%
#
#
#
#
#
#
#
#
#
#
#
#
# pyogrio-0.10.0       | 782 KB    | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# pyogrio-0.10.0       | 782 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libkml-1.3.0         | 418 KB    | #4                                    |   4%
#
# proj-9.3.1           | 2.8 MB    | ##########7                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libkml-1.3.0         | 418 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pyogrio-0.10.0       | 782 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.1    | 252 KB    | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mapclassify-2.9.0    | 583 KB    | #############1                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 551 KB    | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.1    | 252 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 700 KB    | #####################9                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libkml-1.3.0         | 418 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.1    | 252 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nspr-4.35            | 243 KB    | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nspr-4.35            | 243 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nspr-4.35            | 243 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 196 KB    | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 196 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 196 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kealib-1.5.0         | 144 KB    | ####1                                 |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kealib-1.5.0         | 144 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kealib-1.5.0         | 144 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 700 KB    | #############################5        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mapclassify-2.9.0    | 583 KB    | ##################2                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 551 KB    | ######4                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 700 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 700 KB    | ##################################### | 100%
#
# proj-9.3.1           | 2.8 MB    | ###########1                          |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mapclassify-2.9.0    | 583 KB    | #########################3            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 551 KB    | ##########7                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mapclassify-2.9.0    | 583 KB    | ##################################4   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mapclassify-2.9.0    | 583 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mapclassify-2.9.0    | 583 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 551 KB    | ###############                       |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 551 KB    | ####################4                 |  55%
#
# proj-9.3.1           | 2.8 MB    | ###########5                          |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 551 KB    | ##########################8           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 551 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 551 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 551 KB    | ##################################### | 100%
#
# proj-9.3.1           | 2.8 MB    | ###########9                          |  32%
#
# proj-9.3.1           | 2.8 MB    | ############3                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# proj-9.3.1           | 2.8 MB    | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# proj-9.3.1           | 2.8 MB    | #############2                        |  36%
#
# proj-9.3.1           | 2.8 MB    | #############6                        |  37%
#
# proj-9.3.1           | 2.8 MB    | ##############                        |  38%
#
# proj-9.3.1           | 2.8 MB    | ##############4                       |  39%
#
# proj-9.3.1           | 2.8 MB    | ##############8                       |  40%
#
# proj-9.3.1           | 2.8 MB    | ###############                       |  41%
#
# proj-9.3.1           | 2.8 MB    | ###############2                      |  41%
#
# proj-9.3.1           | 2.8 MB    | ###############4                      |  42%
#
# proj-9.3.1           | 2.8 MB    | ###############6                      |  42%
#
# proj-9.3.1           | 2.8 MB    | ###############9                      |  43%
#
# proj-9.3.1           | 2.8 MB    | ################1                     |  44%
#
# proj-9.3.1           | 2.8 MB    | ################3                     |  44%
#
# proj-9.3.1           | 2.8 MB    | ################5                     |  45%
#
# proj-9.3.1           | 2.8 MB    | ################7                     |  45%
#
# proj-9.3.1           | 2.8 MB    | ################9                     |  46%
#
# proj-9.3.1           | 2.8 MB    | #################1                    |  46%
#
# proj-9.3.1           | 2.8 MB    | #################3                    |  47%
#
# proj-9.3.1           | 2.8 MB    | #################5                    |  47%
#
# proj-9.3.1           | 2.8 MB    | #################7                    |  48%
#
# proj-9.3.1           | 2.8 MB    | #################9                    |  49%
#
# proj-9.3.1           | 2.8 MB    | ##################1                   |  49%
#
# proj-9.3.1           | 2.8 MB    | ##################3                   |  50%
#
# proj-9.3.1           | 2.8 MB    | ##################5                   |  50%
#
# proj-9.3.1           | 2.8 MB    | ##################7                   |  51%
#
# proj-9.3.1           | 2.8 MB    | ###################                   |  51%
#
# proj-9.3.1           | 2.8 MB    | ###################2                  |  52%
#
# proj-9.3.1           | 2.8 MB    | ###################4                  |  52%
#
# proj-9.3.1           | 2.8 MB    | ###################6                  |  53%
#
# proj-9.3.1           | 2.8 MB    | ###################8                  |  54%
#
# proj-9.3.1           | 2.8 MB    | ####################                  |  54%
#
# proj-9.3.1           | 2.8 MB    | ####################2                 |  55%
#
# proj-9.3.1           | 2.8 MB    | ####################4                 |  55%
#
# proj-9.3.1           | 2.8 MB    | ####################6                 |  56%
#
# proj-9.3.1           | 2.8 MB    | ####################8                 |  56%
#
# proj-9.3.1           | 2.8 MB    | #####################                 |  57%
#
# proj-9.3.1           | 2.8 MB    | #####################2                |  57%
#
# proj-9.3.1           | 2.8 MB    | #####################4                |  58%
#
# proj-9.3.1           | 2.8 MB    | #####################6                |  59%
#
# proj-9.3.1           | 2.8 MB    | #####################8                |  59%
#
# proj-9.3.1           | 2.8 MB    | ######################                |  60%
#
# proj-9.3.1           | 2.8 MB    | ######################5               |  61%
#
# proj-9.3.1           | 2.8 MB    | ######################7               |  61%
#
# proj-9.3.1           | 2.8 MB    | ######################9               |  62%
#
# proj-9.3.1           | 2.8 MB    | #######################1              |  63%
#
# proj-9.3.1           | 2.8 MB    | #######################3              |  63%
#
# proj-9.3.1           | 2.8 MB    | #######################5              |  64%
#
# proj-9.3.1           | 2.8 MB    | #######################7              |  64%
#
# proj-9.3.1           | 2.8 MB    | ########################1             |  65%
#
# proj-9.3.1           | 2.8 MB    | ########################3             |  66%
#
# proj-9.3.1           | 2.8 MB    | ########################5             |  66%
#
# proj-9.3.1           | 2.8 MB    | ########################7             |  67%
#
# proj-9.3.1           | 2.8 MB    | ########################9             |  68%
#
# proj-9.3.1           | 2.8 MB    | #########################1            |  68%
#
# proj-9.3.1           | 2.8 MB    | #########################4            |  69%
#
# proj-9.3.1           | 2.8 MB    | #########################6            |  69%
#
# proj-9.3.1           | 2.8 MB    | #########################8            |  70%
#
# proj-9.3.1           | 2.8 MB    | ##########################            |  70%
#
# proj-9.3.1           | 2.8 MB    | ##########################2           |  71%
#
# proj-9.3.1           | 2.8 MB    | ##########################4           |  71%
#
# proj-9.3.1           | 2.8 MB    | ##########################6           |  72%
#
# proj-9.3.1           | 2.8 MB    | ##########################8           |  73%
#
# proj-9.3.1           | 2.8 MB    | ###########################           |  73%
#
# proj-9.3.1           | 2.8 MB    | ###########################2          |  74%
#
# proj-9.3.1           | 2.8 MB    | ###########################6          |  75%
#
# proj-9.3.1           | 2.8 MB    | ###########################8          |  75%
#
# proj-9.3.1           | 2.8 MB    | ############################          |  76%
#
# proj-9.3.1           | 2.8 MB    | ############################5         |  77%
#
# proj-9.3.1           | 2.8 MB    | ############################7         |  78%
#
# proj-9.3.1           | 2.8 MB    | ############################9         |  78%
#
# proj-9.3.1           | 2.8 MB    | #############################1        |  79%
#
# proj-9.3.1           | 2.8 MB    | #############################3        |  79%
#
# proj-9.3.1           | 2.8 MB    | #############################5        |  80%
#
# proj-9.3.1           | 2.8 MB    | #############################7        |  80%
#
# proj-9.3.1           | 2.8 MB    | ##############################1       |  81%
#
# proj-9.3.1           | 2.8 MB    | ##############################3       |  82%
#
# proj-9.3.1           | 2.8 MB    | ##############################5       |  83%
#
# proj-9.3.1           | 2.8 MB    | ##############################7       |  83%
#
# proj-9.3.1           | 2.8 MB    | ##############################9       |  84%
#
# proj-9.3.1           | 2.8 MB    | ###############################1      |  84%
#
# proj-9.3.1           | 2.8 MB    | ###############################3      |  85%
#
# proj-9.3.1           | 2.8 MB    | ###############################6      |  85%
#
# proj-9.3.1           | 2.8 MB    | ###############################8      |  86%
#
# proj-9.3.1           | 2.8 MB    | ################################      |  87%
#
# proj-9.3.1           | 2.8 MB    | ################################2     |  87%
#
# proj-9.3.1           | 2.8 MB    | ################################4     |  88%
#
# proj-9.3.1           | 2.8 MB    | ################################6     |  88%
#
# proj-9.3.1           | 2.8 MB    | ################################8     |  89%
#
# proj-9.3.1           | 2.8 MB    | #################################     |  89%
#
# proj-9.3.1           | 2.8 MB    | #################################4    |  90%
#
# proj-9.3.1           | 2.8 MB    | #################################8    |  92%
#
# proj-9.3.1           | 2.8 MB    | ##################################    |  92%
#
# proj-9.3.1           | 2.8 MB    | ##################################2   |  93%
#
# proj-9.3.1           | 2.8 MB    | ##################################4   |  93%
#
# proj-9.3.1           | 2.8 MB    | ##################################6   |  94%
#
# proj-9.3.1           | 2.8 MB    | ##################################9   |  94%
#
# proj-9.3.1           | 2.8 MB    | ###################################1  |  95%
#
# proj-9.3.1           | 2.8 MB    | ###################################3  |  95%
#
# proj-9.3.1           | 2.8 MB    | ###################################5  |  96%
#
# proj-9.3.1           | 2.8 MB    | ###################################7  |  97%
#
# proj-9.3.1           | 2.8 MB    | ###################################9  |  97%
#
# proj-9.3.1           | 2.8 MB    | ####################################1 |  98%
#
# proj-9.3.1           | 2.8 MB    | ####################################3 |  98%
#
# proj-9.3.1           | 2.8 MB    | ####################################5 |  99%
#
# proj-9.3.1           | 2.8 MB    | ##################################### | 100%
#
# proj-9.3.1           | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
mission_antyodaya_df = pd.read_excel(r'D:\CivicDataLabs_IDS-DRR\IDS-DRR_Github\flood-data-ecosystem-Odisha\Sources\ANTYODAYA\Odisha_antyodaya_village_dataset.xlsx')

# %%
mission_antyodaya_df.shape
# Out:
# (49535, 202)

# %%
mission_antyodaya_geometry = [
        Point(xy) for xy in zip(
            mission_antyodaya_df.village_longitude,
            mission_antyodaya_df.village_latitude
        )
    ]

# %%
gdf_points = GeoDataFrame(mission_antyodaya_df, geometry=mission_antyodaya_geometry)

# %%
# importing odisha subdistrict shapefile as proxy for revenue circles
gdf_polygons = gpd.read_file(r'D:\CivicDataLabs_IDS-DRR\IDS-DRR_Github\flood-data-ecosystem-Odisha\Maps\Geojson\bharatmaps_odisha_subdistrict.geojson')
#gdf_polygons = gdf_polygons.rename(columns = {'SDTCODE11':'sub_district_code'}, inplace = True)

# %%
gdf_points.crs = gdf_polygons.crs

# %%
result = gpd.sjoin(gdf_points, gdf_polygons, how="left", op="within")
# Out:
# d:\CivicDataLabs_IDS-DRR\IDS-DRR_Github\.conda\Lib\site-packages\IPython\core\interactiveshell.py:3517: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
result.tail()
# Out:
#        state_code state_name  district_code district_name  sub_district_code  \
# 49530          21     ODISHA            350       CUTTACK               2946
# 49531          21     ODISHA            359     KANDHAMAL               3121
# 49532          21     ODISHA            359     KANDHAMAL               3123
# 49533          21     ODISHA            359     KANDHAMAL               3123
# 49534          21     ODISHA            359     KANDHAMAL               3123
#
#       sub_district_name  block_code block_name  gp_code      gp_name  ...  \
# 49530           Badamba        3333    BADAMBA   116877  GOPAMATHURA  ...
# 49531      Tumudibandha        3428   KOTAGARH   118953     PARIGARH  ...
# 49532          Kotagarh        3428   KOTAGARH   118953     PARIGARH  ...
# 49533          Kotagarh        3428   KOTAGARH   118953     PARIGARH  ...
# 49534          Kotagarh        3428   KOTAGARH   118953     PARIGARH  ...
#
#       dtcode11 sdtcode11   Shape_Length    Shape_Area  stname     dtname  \
# 49530      381     02946  102031.183065  4.209133e+08  ODISHA    Cuttack
# 49531      390     03119  290666.251003  1.273240e+09  ODISHA  Kandhamal
# 49532      390     03119  290666.251003  1.273240e+09  ODISHA  Kandhamal
# 49533      390     03119  290666.251003  1.273240e+09  ODISHA  Kandhamal
# 49534      390     03119  290666.251003  1.273240e+09  ODISHA  Kandhamal
#
#         sdtname  Subdt_LGD  Dist_LGD  State_LGD
# 49530   Badamba     2946.0     350.0       21.0
# 49531  Baliguda     3119.0     359.0       21.0
# 49532  Baliguda     3119.0     359.0       21.0
# 49533  Baliguda     3119.0     359.0       21.0
# 49534  Baliguda     3119.0     359.0       21.0
#
# [5 rows x 216 columns]

# %%
result.shape
# Out:
# (49540, 216)

# %%
empty_sdtname_rows = result['sdtname'].isnull() | (result['sdtname'] == '')

filtered_df = result[empty_sdtname_rows]

filtered_df
# Out:
#        state_code state_name  district_code district_name  sub_district_code  \
# 70             21     ODISHA            353      GAJAPATI               3105
# 148            21     ODISHA            367      NAYAGARH               3027
# 264            21     ODISHA            353      GAJAPATI               3103
# 326            21     ODISHA            370      RAYAGADA               3177
# 381            21     ODISHA            370      RAYAGADA               3177
# ...           ...        ...            ...           ...                ...
# 49464          21     ODISHA            370      RAYAGADA               3177
# 49465          21     ODISHA            370      RAYAGADA               3177
# 49475          21     ODISHA            370      RAYAGADA               3177
# 49478          21     ODISHA            346     BALESHWAR               2893
# 49513          21     ODISHA            370      RAYAGADA               3177
#
#       sub_district_name  block_code block_name  gp_code      gp_name  ...  \
# 70       Paralakhemundi        3358      GUMMA   117468    MUNISINGI  ...
# 148            Fategarh        3523     BHAPUR   120598  GOLAPOKHARI  ...
# 264             Serango        3358      GUMMA   117468    MUNISINGI  ...
# 326            Kashipur        3552    KASIPUR   121189      SIRIPAI  ...
# 381            Kashipur        3552    KASIPUR   121189      SIRIPAI  ...
# ...                 ...         ...        ...      ...          ...  ...
# 49464          Kashipur        3552    KASIPUR   121177    GODIBALLI  ...
# 49465          Kashipur        3552    KASIPUR   121177    GODIBALLI  ...
# 49475          Kashipur        3552    KASIPUR   121177    GODIBALLI  ...
# 49478          Baliapal        3300   BALIAPAL   116093         ASTI  ...
# 49513          Kashipur        3552    KASIPUR   121177    GODIBALLI  ...
#
#       dtcode11 sdtcode11 Shape_Length  Shape_Area  stname dtname  sdtname  \
# 70         NaN       NaN          NaN         NaN     NaN    NaN      NaN
# 148        NaN       NaN          NaN         NaN     NaN    NaN      NaN
# 264        NaN       NaN          NaN         NaN     NaN    NaN      NaN
# 326        NaN       NaN          NaN         NaN     NaN    NaN      NaN
# 381        NaN       NaN          NaN         NaN     NaN    NaN      NaN
# ...        ...       ...          ...         ...     ...    ...      ...
# 49464      NaN       NaN          NaN         NaN     NaN    NaN      NaN
# 49465      NaN       NaN          NaN         NaN     NaN    NaN      NaN
# 49475      NaN       NaN          NaN         NaN     NaN    NaN      NaN
# 49478      NaN       NaN          NaN         NaN     NaN    NaN      NaN
# 49513      NaN       NaN          NaN         NaN     NaN    NaN      NaN
#
#        Subdt_LGD  Dist_LGD  State_LGD
# 70           NaN       NaN        NaN
# 148          NaN       NaN        NaN
# 264          NaN       NaN        NaN
# 326          NaN       NaN        NaN
# 381          NaN       NaN        NaN
# ...          ...       ...        ...
# 49464        NaN       NaN        NaN
# 49465        NaN       NaN        NaN
# 49475        NaN       NaN        NaN
# 49478        NaN       NaN        NaN
# 49513        NaN       NaN        NaN
#
# [2016 rows x 216 columns]

# %%
empty_sdtname_rows = result['sub_district_name'].isnull() | (result['sub_district_name'] == '')

filtered_df = result[empty_sdtname_rows]

filtered_df
# Out:
# Empty GeoDataFrame
# Columns: [state_code, state_name, district_code, district_name, sub_district_code, sub_district_name, block_code, block_name, gp_code, gp_name, village_code, village_name, village_pin_code, pc_code, ac_code, other_assembly_constituencies, total_population, male_population, female_population, total_hhd, total_hhd_engaged_in_farm_activities, total_hhd_engaged_in_non_farm_activities, is_govt_seed_centre_available, distance_of_govt_seed_centre, availability_of_watershed_dev_project, availability_of_rain_harvest_system, availability_of_fpos_pacs, availability_of_food_storage_warehouse, distance_of_food_storage_warehouse, availability_of_farm_gate_processing, availability_of_custom_hiring_centre_agri_equipment, total_cultivable_area_in_hac, net_sown_area_in_hac, net_sown_area_kharif_in_hac, net_sown_area_rabi_in_hac, net_sown_area_other_in_hac, is_soil_testing_centre_available, distance_of_soil_testing_centre, is_fertilizer_shop_available, distance_of_fertilizer_shop, availability_of_major_source_of_irrigation, no_of_farmers_using_drip_sprinkler, area_irrigated_in_hac, total_unirrigated_land_area_in_hac, availability_of_livestock_extension_services, availability_of_milk_routes, availability_of_poultry_dev_project, availability_of_goatary_dev_project, availability_of_pigery_development, is_veterinary_hospital_available, distance_of_veterinary_hospital, availability_of_fish_community_ponds, availability_of_fish_farming, availability_of_aquaculture_ext_facility, distance_of_aquaculture_ext_facility, total_hhd_with_kuccha_wall_kuccha_roof, total_hhd_have_got_pmay_house, total_hhd_in_pmay_permanent_wait_list, total_hhd_got_benefit_under_state_housing_scheme, total_hhd_in_perm_waitlist_under_state_housing_scheme, availability_of_piped_tap_water, distance_of_piped_tap_water, is_village_connected_to_all_weather_road, distance_of_all_weather_road, availability_of_internal_pucca_road, availability_of_public_transport, distance_of_public_transport, availability_of_railway_station, distance_of_railway_station, availablility_hours_of_domestic_electricity, total_hhd_having_pmsbhgy_benefit, availability_of_elect_supply_to_msme, availability_of_solor_wind_energy, total_hhd_having_solor_wind_energy, availability_of_panchayat_bhawan, availability_of_csc_in_village, availability_of_public_information_board, is_common_pastures_available, total_hhd_availing_pmuy_benefits, availability_of_public_library, distance_of_public_library, availability_of_recreational_centre, is_bank_available, distance_of_banks, is_bank_buss_correspondent_with_internet, is_atm_available, distance_of_atm, total_hhd_availing_pmjdy_bank_ac, is_post_office_available, distance_of_post_office, availability_of_telephone_services, is_broadband_available, is_pds_available, distance_of_pds_office, total_hhd_having_bpl_cards, availability_of_primary_school, is_primary_school_with_electricity, primary_school_toilet, is_primary_school_with_computer_lab, is_primary_school_with_playground, ...]
# Index: []
#
# [0 rows x 216 columns]

# %%
#renaming sub-district code columns to match
gdf_polygons_renamed = gdf_polygons.rename(columns = {'sdtcode11':'sub_district_code'})

# %%
#gdf_polygons and bharat_maps_villages have slightly different sub-district codes. removing unnecessary trailing'0'
gdf_polygons_renamed['sub_district_code'] = gdf_polygons_renamed['sub_district_code'].apply(lambda x: x[1:] if x.startswith('0') else x)
gdf_polygons_renamed
# Out:
#      OBJECTID stcode11 dtcode11 sub_district_code   Shape_Length  \
# 0        2773       21      370              2755  175809.421683
# 1        2774       21      370              2756  192057.189614
# 2        2775       21      370              2757  133403.031651
# 3        2776       21      370              2758  113949.812620
# 4        2777       21      370              2759  135841.048349
# ..        ...      ...      ...               ...            ...
# 473      3246       21      399              3226  149569.992418
# 474      3247       21      399              3227  269711.225643
# 475      3248       21      399              3228  129218.450510
# 476      3249       21      399              3229  130042.312962
# 477      3250       21      399              3230  130653.122822
#
#        Shape_Area  stname      dtname     sdtname  Subdt_LGD  Dist_LGD  \
# 0    6.516630e+08  ODISHA     Bargarh    Paikamal       2755       347
# 1    7.626096e+08  ODISHA     Bargarh  Jharbandha       2756       347
# 2    3.456675e+08  ODISHA     Bargarh    Padmapur       2757       347
# 3    2.672039e+08  ODISHA     Bargarh  BurdenP.S.       2758       347
# 4    3.752092e+08  ODISHA     Bargarh    Gaisilet       2759       347
# ..            ...     ...         ...         ...        ...       ...
# 473  5.100200e+08  ODISHA  Malkangiri       Orkel       3226       364
# 474  9.885963e+08  ODISHA  Malkangiri    Kalimela       3227       364
# 475  4.291734e+08  ODISHA  Malkangiri       Podia       3228       364
# 476  3.676498e+08  ODISHA  Malkangiri     M.V. 79       3229       364
# 477  4.129349e+08  ODISHA  Malkangiri        Motu       3230       364
#
#      State_LGD                                           geometry
# 0           21  POLYGON ((82.90633 21.04445, 82.90599 21.04534...
# 1           21  POLYGON ((82.96518 21.19248, 82.96504 21.19318...
# 2           21  POLYGON ((83.16820 21.13856, 83.16775 21.13887...
# 3           21  POLYGON ((83.12346 20.98452, 83.12192 20.98650...
# 4           21  POLYGON ((83.28376 21.04885, 83.28268 21.04889...
# ..         ...                                                ...
# 473         21  POLYGON ((82.16914 18.48265, 82.16793 18.48307...
# 474         21  POLYGON ((81.72320 18.29129, 81.72195 18.29135...
# 475         21  POLYGON ((81.66331 18.32195, 81.66271 18.32223...
# 476         21  POLYGON ((81.64158 18.10071, 81.64075 18.10174...
# 477         21  POLYGON ((81.65802 18.00632, 81.65699 18.00799...
#
# [478 rows x 13 columns]

# %%
#The splitting into tagged+untagged has been skipped as all the points seem to have an associated subdistrict - leaving it in in case this needs to be changed later
#untagged = result[result.sdtname.isnull()]
#tagged = result.dropna(subset=['sdtname'])

# %%
#tagged.shape
# Out:
# (47524, 216)

# %%
#untagged.shape
# Out:
# (2016, 216)

# %%
def format_entry(entry):
    if pd.isnull(entry):
        return entry
    entry = entry.lower()              # Convert to lowercase
    entry = entry.replace(' ', '_')    # Replace spaces with underscores
    entry = entry.replace('.', '-')    # Replace periods with hyphens
    return entry

# Apply the function to the specific column
result['sub_district_name'] = result['sub_district_name'].apply(format_entry)

# %%
#Original code for revenue circles - not removing as it may be required later
result_bm = bharat_maps_villages[bharat_maps_villages.VILCODE11.isin(result.village_code.to_list())]
result_bm['geometry'] = result_bm.geometry.centroid
result_bm = result_bm.to_crs('EPSG:4326')
result_bm = gpd.sjoin(result_bm, gdf_polygons, how="left", op="within")
# Out:
# d:\CivicDataLabs_IDS-DRR\IDS-DRR_Github\.conda\Lib\site-packages\IPython\core\interactiveshell.py:3517: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
'''untagged = pd.merge(untagged.drop(['sub_district_code','sdtname'],axis=1),untagged_bm[['VILCODE11','sub_district_code','sdtname']],
        left_on='village_code', right_on='vil_lgd')[untagged.columns]
        '''
# Out:
# "untagged = pd.merge(untagged.drop(['sub_district_code','sdtname'],axis=1),untagged_bm[['VILCODE11','sub_district_code','sdtname']],\n        left_on='village_code', right_on='vil_lgd')[untagged.columns]\n        "

# %%
#result = pd.concat([tagged,untagged])

# %%
#result.to_csv(r'D:\CivicDataLabs_IDS-DRR\IDS-DRR_Github\flood-data-ecosystem-Odisha\Sources\ANTYODAYA\data/MissionAntyodaya2020_Odisha_untaggedRC.csv')

# %%
result[['gp_code','village_code','sub_district_code','sub_district_name','net_sown_area_in_hac','total_hhd',
        'availablility_hours_of_domestic_electricity', 'availability_of_telephone_services',
       'total_hhd_having_piped_water_connection', 'total_hhd_not_having_sanitary_latrines']].to_csv(
    r'D:\CivicDataLabs_IDS-DRR\IDS-DRR_Github\flood-data-ecosystem-Odisha\Sources\ANTYODAYA\data\MissionAntyodaya2020_Odisha_vul.csv', index=False)

# %%
#original with revenue circle
''' result[['gp_code','village_code','object_id','revenue_ci','net_sown_area_in_hac','total_hhd',
        'availablility_hours_of_domestic_electricity', 'availability_of_telephone_services',
       'total_hhd_having_piped_water_connection', 'total_hhd_not_having_sanitary_latrines']].to_csv(
    r'D:\CivicDataLabs_IDS-DRR\IDS-DRR_Github\flood-data-ecosystem-Odisha\Sources\ANTYODAYA\data\MissionAntyodaya2020_Odisha_vul.csv', index=False)'''
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\saura\AppData\Local\Temp\ipykernel_20836\1810735516.py:2: SyntaxWarning: invalid escape sequence '\C'
#   ''' result[['gp_code','village_code','object_id','revenue_ci','net_sown_area_in_hac','total_hhd',
# " result[['gp_code','village_code','object_id','revenue_ci','net_sown_area_in_hac','total_hhd',\n        'availablility_hours_of_domestic_electricity', 'availability_of_telephone_services',\n       'total_hhd_having_piped_water_connection', 'total_hhd_not_having_sanitary_latrines']].to_csv(\n    r'D:\\CivicDataLabs_IDS-DRR\\IDS-DRR_Github\x0clood-data-ecosystem-Odisha\\Sources\\ANTYODAYA\\data\\MissionAntyodaya2020_Odisha_vul.csv', index=False)"

# %% [markdown]
# # Number of households in each urban area

# %%
od_urban_shapes = gpd.read_file(r'D:\CivicDataLabs_IDS-DRR\IDS-DRR_Github\flood-data-ecosystem-Odisha\Maps\Geojson\od_urban_shapes.geojson')
od_urban_shapes =  od_urban_shapes.loc[od_urban_shapes['STCODE11'] == "21"]

od_urban_shapes
# Out:
#              VILNAM_SOI      DTNAME STCODE11 DTCODE11 SDTCODE11 VILCODE11  \
# 17           BADASAILUR  MALKANGIRI       21      399     03227    431042
# 22             IDIGUNDA  MALKANGIRI       21      399     03229    431113
# 25          BEJANGIBARA  MALKANGIRI       21      399     03227    431007
# 26            UDAYAGIRI  MALKANGIRI       21      399     03228    431094
# 31            BOILAPARI  MALKANGIRI       21      399     03220    430262
# ...                 ...         ...      ...      ...       ...       ...
# 2264            GOLAPUR        PURI       21      387     03069    410169
# 2267         JATNI TOWN     KHORDHA       21      386     03049    801856
# 2268       GADAJAGASORA     KHORDHA       21      386     03049    407791
# 2269  NARSINHPUR PATANA        PURI       21      387     03066    409877
# 2270            JORANDA   DHENKANAL       21      383     02991    402708
#
#              SDTNAME           VILNAME11  \
# 17          Kalimela          Badasailur
# 22           M.V. 79            Idigunda
# 25          Kalimela         Bejangiwada
# 26             Podia            Udaygiri
# 31        Malkangiri           Boilapari
# ...              ...                 ...
# 2264  Krushna Prasad              Golpur
# 2267          Jatani     Jatani (M + OG)
# 2268          Jatani        Gadajagasora
# 2269           Sadar  Narasinghpurpattna
# 2270          Gandia             Joranda
#
#                                                geometry
# 17    MULTIPOLYGON (((9101716.619 2032051.604, 91018...
# 22    MULTIPOLYGON (((9096169.156 2039524.804, 90960...
# 25    MULTIPOLYGON (((9115672.266 2052834.835, 91158...
# 26    MULTIPOLYGON (((9080064.169 2049151.499, 90801...
# 31    MULTIPOLYGON (((9118571.698 2075445.348, 91187...
# ...                                                 ...
# 2264  MULTIPOLYGON (((9503078.330 2229722.401, 95030...
# 2267  MULTIPOLYGON (((9539863.910 2293150.772, 95401...
# 2268  MULTIPOLYGON (((9542383.998 2300776.351, 95423...
# 2269  MULTIPOLYGON (((9541834.044 2248153.937, 95417...
# 2270  MULTIPOLYGON (((9543272.268 2367356.300, 95433...
#
# [1516 rows x 9 columns]

# %%
od_urban_shapes = od_urban_shapes[~(od_urban_shapes['geometry'].is_empty | od_urban_shapes['geometry'].isna())]

# %%
# TOTAL POPULATION IN EACH URBAN AREA
import rasterio
import rasterstats

worldpop_raster = rasterio.open(r'D:\CivicDataLabs_IDS-DRR\IDS-DRR_Github\Explorations\flood-data-ecosystem-Odisha\Sources\WORLDPOP\odisha_ppp_2020_UNadj.tif')
worldpop_raster_array = worldpop_raster.read(1)

sum_dicts = rasterstats.zonal_stats(od_urban_shapes.to_crs(worldpop_raster.crs),
                                     worldpop_raster_array,
                                     affine= worldpop_raster.transform,
                                     stats= ['sum'],
                                     nodata=worldpop_raster.nodata,
                                     geojson_out = True)

dfs = []
for sd in sum_dicts:
    dfs.append(pd.DataFrame([sd['properties']]))

pop_zonal_stats_df = pd.concat(dfs).reset_index(drop=True)
pop_zonal_stats_df = pop_zonal_stats_df.rename(columns={'sum':'sum_population'})
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_20836\1234119094.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pop_zonal_stats_df = pd.concat(dfs).reset_index(drop=True)

# %%
# Divide population by 4.3 for households
pop_zonal_stats_df['urban_hhd'] = pop_zonal_stats_df['sum_population']/4.3

# %%
urban_hhd = pop_zonal_stats_df.groupby('SDTCODE11')[['urban_hhd']].sum().reset_index()
urban_hhd
# Out:
#     SDTCODE11    urban_hhd
# 0       02757  3550.205901
# 1       02758    69.622380
# 2       02760   119.142451
# 3       02762  1485.231061
# 4       02763  6514.601277
# ..        ...          ...
# 264     03225   768.809206
# 265     03226   904.969262
# 266     03227   515.483437
# 267     03228   163.390616
# 268     03229   235.294260
#
# [269 rows x 2 columns]

# %%
urban_hhd['urban_electricity'] = urban_hhd['urban_hhd']*20

# %%
urban_hhd['urban_tele'] = urban_hhd['urban_hhd']*3

# %%
urban_hhd['urban_hhd_pipe'] = urban_hhd['urban_hhd']*0.1873

# %%
urban_hhd['urban_no_sanitation'] = urban_hhd['urban_hhd']*0.063

# %%
urban_hhd = urban_hhd.rename(columns={'SDTCODE11': 'sub_district_code'})

# %%
urban_hhd['sub_district_code'] = urban_hhd['sub_district_code'].apply(lambda x: x[1:] if x.startswith('0') else x)
urban_hhd
# Out:
#     sub_district_code    urban_hhd  urban_electricity    urban_tele  \
# 0                2757  3550.205901       71004.118028  10650.617704
# 1                2758    69.622380        1392.447609    208.867141
# 2                2760   119.142451        2382.849015    357.427352
# 3                2762  1485.231061       29704.621213   4455.693182
# 4                2763  6514.601277      130292.025544  19543.803832
# ..                ...          ...                ...           ...
# 264              3225   768.809206       15376.184118   2306.427618
# 265              3226   904.969262       18099.385248   2714.907787
# 266              3227   515.483437       10309.668749   1546.450312
# 267              3228   163.390616        3267.812330    490.171849
# 268              3229   235.294260        4705.885208    705.882781
#
#      urban_hhd_pipe  urban_no_sanitation
# 0        664.953565           223.662972
# 1         13.040272             4.386210
# 2         22.315381             7.505974
# 3        278.183778            93.569557
# 4       1220.184819           410.419880
# ..              ...                  ...
# 264      143.997964            48.434980
# 265      169.500743            57.013064
# 266       96.550048            32.475457
# 267       30.603062            10.293609
# 268       44.070615            14.823538
#
# [269 rows x 6 columns]

# %% [markdown]
# # Vul variables

# %%
vul_df = pd.read_csv(r'D:\CivicDataLabs_IDS-DRR\IDS-DRR_Github\flood-data-ecosystem-Odisha\Sources\ANTYODAYA\data\MissionAntyodaya2020_Odisha_vul.csv')

# %%
vul_df = vul_df.rename(columns={'total_hhd':'rural_hhd'})
vul_df['sub_district_code'] = vul_df['sub_district_code'].astype(str)

# %% [markdown]
# ## net_sown_area_in_hac

# %%
#original 
net_sown_area_in_hac_sd = vul_df.groupby(['sub_district_code'])[['net_sown_area_in_hac']].sum()

# %%
net_sown_area_in_hac_sd = vul_df.groupby(['sub_district_code'])[['net_sown_area_in_hac']].sum()

# %%
net_sown_area_in_hac_sd
# Out:
#                    net_sown_area_in_hac
# sub_district_code
# 2755                          20637.310
# 2756                          24144.640
# 2757                          14361.820
# 2758                           8136.000
# 2759                          11586.370
# ...                                 ...
# 3226                           9017.210
# 3227                           7170.903
# 3228                           7906.389
# 3229                           5896.254
# 3230                           7852.980
#
# [465 rows x 1 columns]

# %% [markdown]
# ## Rural - Urban Households in each rc

# %%
rural_hhd = vul_df.groupby('sub_district_code')[['rural_hhd']].sum().reset_index()
rural_hhd
# Out:
#     sub_district_code  rural_hhd
# 0                2755      23627
# 1                2756      31699
# 2                2757      17150
# 3                2758       8776
# 4                2759      21890
# ..                ...        ...
# 460              3226      14580
# 461              3227      31236
# 462              3228       6899
# 463              3229      14013
# 464              3230       9344
#
# [465 rows x 2 columns]

# %%
vul_df[vul_df.sub_district_code == 2755]
# Out:
# Empty DataFrame
# Columns: [gp_code, village_code, sub_district_code, sub_district_name, net_sown_area_in_hac, rural_hhd, availablility_hours_of_domestic_electricity, availability_of_telephone_services, total_hhd_having_piped_water_connection, total_hhd_not_having_sanitary_latrines]
# Index: []

# %%
#urban_hhd['sub_district_code'] = urban_hhd['sub_district_code'].astype(str)
total_hhd = urban_hhd.merge(rural_hhd, how='outer', on='sub_district_code')
total_hhd
# Out:
#     sub_district_code    urban_hhd  urban_electricity    urban_tele  \
# 0                2755          NaN                NaN           NaN
# 1                2756          NaN                NaN           NaN
# 2                2757  3550.205901       71004.118028  10650.617704
# 3                2758    69.622380        1392.447609    208.867141
# 4                2759          NaN                NaN           NaN
# ..                ...          ...                ...           ...
# 469              3226   904.969262       18099.385248   2714.907787
# 470              3227   515.483437       10309.668749   1546.450312
# 471              3228   163.390616        3267.812330    490.171849
# 472              3229   235.294260        4705.885208    705.882781
# 473              3230          NaN                NaN           NaN
#
#      urban_hhd_pipe  urban_no_sanitation  rural_hhd
# 0               NaN                  NaN    23627.0
# 1               NaN                  NaN    31699.0
# 2        664.953565           223.662972    17150.0
# 3         13.040272             4.386210     8776.0
# 4               NaN                  NaN    21890.0
# ..              ...                  ...        ...
# 469      169.500743            57.013064    14580.0
# 470       96.550048            32.475457    31236.0
# 471       30.603062            10.293609     6899.0
# 472       44.070615            14.823538    14013.0
# 473             NaN                  NaN     9344.0
#
# [474 rows x 7 columns]

# %%
total_hhd = total_hhd.fillna(0)
total_hhd['total_hhd']=total_hhd['rural_hhd']+total_hhd['urban_hhd']

# %%
total_hhd
# Out:
#     sub_district_code    urban_hhd  urban_electricity    urban_tele  \
# 0                2755     0.000000           0.000000      0.000000
# 1                2756     0.000000           0.000000      0.000000
# 2                2757  3550.205901       71004.118028  10650.617704
# 3                2758    69.622380        1392.447609    208.867141
# 4                2759     0.000000           0.000000      0.000000
# ..                ...          ...                ...           ...
# 469              3226   904.969262       18099.385248   2714.907787
# 470              3227   515.483437       10309.668749   1546.450312
# 471              3228   163.390616        3267.812330    490.171849
# 472              3229   235.294260        4705.885208    705.882781
# 473              3230     0.000000           0.000000      0.000000
#
#      urban_hhd_pipe  urban_no_sanitation  rural_hhd     total_hhd
# 0          0.000000             0.000000    23627.0  23627.000000
# 1          0.000000             0.000000    31699.0  31699.000000
# 2        664.953565           223.662972    17150.0  20700.205901
# 3         13.040272             4.386210     8776.0   8845.622380
# 4          0.000000             0.000000    21890.0  21890.000000
# ..              ...                  ...        ...           ...
# 469      169.500743            57.013064    14580.0  15484.969262
# 470       96.550048            32.475457    31236.0  31751.483437
# 471       30.603062            10.293609     6899.0   7062.390616
# 472       44.070615            14.823538    14013.0  14248.294260
# 473        0.000000             0.000000     9344.0   9344.000000
#
# [474 rows x 8 columns]

# %% [markdown]
# ## availablility_hours_of_domestic_electricity

# %%
# Map category to mean electricity available
electricity_dict = {1:2.5, 2:6, 3:10, 4:12, 5:0}

# %%
elect_df = vul_df.replace({"availablility_hours_of_domestic_electricity": electricity_dict})[['sub_district_code','rural_hhd','availablility_hours_of_domestic_electricity']]

# %%
elect_df['rural_electricity'] = elect_df['rural_hhd']*elect_df['availablility_hours_of_domestic_electricity']

# %%
elect_df = elect_df.groupby('sub_district_code')[['rural_hhd','rural_electricity']].sum().reset_index()

# %%
elect_df
# Out:
#     sub_district_code  rural_hhd  rural_electricity
# 0                2755      23627           203468.5
# 1                2756      31699           307670.0
# 2                2757      17150           169277.5
# 3                2758       8776            97482.0
# 4                2759      21890           207794.0
# ..                ...        ...                ...
# 460              3226      14580           161810.0
# 461              3227      31236           279538.0
# 462              3228       6899            68571.5
# 463              3229      14013           143652.0
# 464              3230       9344           106664.0
#
# [465 rows x 3 columns]

# %%
elect_df['sub_district_code'] = elect_df['sub_district_code'].astype(str)
sd_electricity = elect_df.merge(urban_hhd, on='sub_district_code', how='outer')

# %%
sd_electricity = sd_electricity.fillna(0)

# %%
sd_electricity['total_electricity'] = sd_electricity['rural_electricity'] + sd_electricity['urban_electricity']

# %%
sd_electricity['total_hhd'] = sd_electricity['rural_hhd'] + sd_electricity['urban_hhd']

# %%
sd_electricity
# Out:
#     sub_district_code  rural_hhd  rural_electricity    urban_hhd  \
# 0                2755    23627.0           203468.5     0.000000
# 1                2756    31699.0           307670.0     0.000000
# 2                2757    17150.0           169277.5  3550.205901
# 3                2758     8776.0            97482.0    69.622380
# 4                2759    21890.0           207794.0     0.000000
# ..                ...        ...                ...          ...
# 469              3226    14580.0           161810.0   904.969262
# 470              3227    31236.0           279538.0   515.483437
# 471              3228     6899.0            68571.5   163.390616
# 472              3229    14013.0           143652.0   235.294260
# 473              3230     9344.0           106664.0     0.000000
#
#      urban_electricity    urban_tele  urban_hhd_pipe  urban_no_sanitation  \
# 0             0.000000      0.000000        0.000000             0.000000
# 1             0.000000      0.000000        0.000000             0.000000
# 2         71004.118028  10650.617704      664.953565           223.662972
# 3          1392.447609    208.867141       13.040272             4.386210
# 4             0.000000      0.000000        0.000000             0.000000
# ..                 ...           ...             ...                  ...
# 469       18099.385248   2714.907787      169.500743            57.013064
# 470       10309.668749   1546.450312       96.550048            32.475457
# 471        3267.812330    490.171849       30.603062            10.293609
# 472        4705.885208    705.882781       44.070615            14.823538
# 473           0.000000      0.000000        0.000000             0.000000
#
#      total_electricity     total_hhd
# 0        203468.500000  23627.000000
# 1        307670.000000  31699.000000
# 2        240281.618028  20700.205901
# 3         98874.447609   8845.622380
# 4        207794.000000  21890.000000
# ..                 ...           ...
# 469      179909.385248  15484.969262
# 470      289847.668749  31751.483437
# 471       71839.312330   7062.390616
# 472      148357.885208  14248.294260
# 473      106664.000000   9344.000000
#
# [474 rows x 10 columns]

# %%
sd_electricity['avg_electricity'] = sd_electricity['total_electricity']/sd_electricity['total_hhd']

# %%
sd_electricity
# Out:
#     sub_district_code  rural_hhd  rural_electricity    urban_hhd  \
# 0                2755    23627.0           203468.5     0.000000
# 1                2756    31699.0           307670.0     0.000000
# 2                2757    17150.0           169277.5  3550.205901
# 3                2758     8776.0            97482.0    69.622380
# 4                2759    21890.0           207794.0     0.000000
# ..                ...        ...                ...          ...
# 469              3226    14580.0           161810.0   904.969262
# 470              3227    31236.0           279538.0   515.483437
# 471              3228     6899.0            68571.5   163.390616
# 472              3229    14013.0           143652.0   235.294260
# 473              3230     9344.0           106664.0     0.000000
#
#      urban_electricity    urban_tele  urban_hhd_pipe  urban_no_sanitation  \
# 0             0.000000      0.000000        0.000000             0.000000
# 1             0.000000      0.000000        0.000000             0.000000
# 2         71004.118028  10650.617704      664.953565           223.662972
# 3          1392.447609    208.867141       13.040272             4.386210
# 4             0.000000      0.000000        0.000000             0.000000
# ..                 ...           ...             ...                  ...
# 469       18099.385248   2714.907787      169.500743            57.013064
# 470       10309.668749   1546.450312       96.550048            32.475457
# 471        3267.812330    490.171849       30.603062            10.293609
# 472        4705.885208    705.882781       44.070615            14.823538
# 473           0.000000      0.000000        0.000000             0.000000
#
#      total_electricity     total_hhd  avg_electricity
# 0        203468.500000  23627.000000         8.611694
# 1        307670.000000  31699.000000         9.705984
# 2        240281.618028  20700.205901        11.607692
# 3         98874.447609   8845.622380        11.177783
# 4        207794.000000  21890.000000         9.492645
# ..                 ...           ...              ...
# 469      179909.385248  15484.969262        11.618324
# 470      289847.668749  31751.483437         9.128634
# 471       71839.312330   7062.390616        10.172096
# 472      148357.885208  14248.294260        10.412326
# 473      106664.000000   9344.000000        11.415240
#
# [474 rows x 11 columns]

# %% [markdown]
# ## availability_of_telephone_services

# %%
telephone_df = vul_df.copy()

# %%
telephone_df['rural_tele'] = vul_df['rural_hhd']*vul_df['availability_of_telephone_services']

# %%
telephone_df = telephone_df[['sub_district_code', 'rural_hhd', 'rural_tele']]

# %%
telephone_df = telephone_df.groupby('sub_district_code')[['rural_hhd','rural_tele']].sum().reset_index()

# %%
#dependent on urban_shapes
#rural_hhd['sub_district_code'] = rural_hhd['sub_district_code'].astype(str)
sd_tele = telephone_df.merge(urban_hhd[['sub_district_code', 'urban_hhd','urban_tele']], on='sub_district_code', how='outer')

# %%
sd_tele = sd_tele.fillna(0)

# %%
sd_tele['total_tele'] = sd_tele['rural_tele'] + sd_tele['urban_tele']

# %%
sd_tele['total_hhd'] = sd_tele['rural_hhd'] + sd_tele['urban_hhd']

# %%
sd_tele['avg_tele'] = round(sd_tele['total_tele']/sd_tele['total_hhd'])

# %%
sd_tele
# Out:
#     sub_district_code  rural_hhd  rural_tele    urban_hhd    urban_tele  \
# 0                2755    23627.0     58061.0     0.000000      0.000000
# 1                2756    31699.0     70562.0     0.000000      0.000000
# 2                2757    17150.0     42462.0  3550.205901  10650.617704
# 3                2758     8776.0     22303.0    69.622380    208.867141
# 4                2759    21890.0     58868.0     0.000000      0.000000
# ..                ...        ...         ...          ...           ...
# 469              3226    14580.0     37231.0   904.969262   2714.907787
# 470              3227    31236.0     88106.0   515.483437   1546.450312
# 471              3228     6899.0     19814.0   163.390616    490.171849
# 472              3229    14013.0     31910.0   235.294260    705.882781
# 473              3230     9344.0     21972.0     0.000000      0.000000
#
#        total_tele     total_hhd  avg_tele
# 0    58061.000000  23627.000000       2.0
# 1    70562.000000  31699.000000       2.0
# 2    53112.617704  20700.205901       3.0
# 3    22511.867141   8845.622380       3.0
# 4    58868.000000  21890.000000       3.0
# ..            ...           ...       ...
# 469  39945.907787  15484.969262       3.0
# 470  89652.450312  31751.483437       3.0
# 471  20304.171849   7062.390616       3.0
# 472  32615.882781  14248.294260       2.0
# 473  21972.000000   9344.000000       2.0
#
# [474 rows x 8 columns]

# %% [markdown]
# ## total_hhd_having_piped_water_connection

# %%
pipe_df = vul_df.copy()

# %%
pipe_df = pipe_df.groupby('sub_district_code')[['total_hhd_having_piped_water_connection']].sum().reset_index()

# %%
pipe_df = pipe_df.merge(urban_hhd[['sub_district_code','urban_hhd_pipe']], on='sub_district_code', how='outer')

# %%
pipe_df = pipe_df.fillna(0)

# %%
pipe_df['sd_piped_hhds'] = pipe_df['urban_hhd_pipe'] + pipe_df['total_hhd_having_piped_water_connection']

# %%
pipe_df = pipe_df.merge(total_hhd[['sub_district_code','total_hhd']], on='sub_district_code')

# %%
pipe_df['sd_piped_hhds_pct'] = 100*pipe_df['sd_piped_hhds']/pipe_df['total_hhd']

# %%
pipe_df
# Out:
#     sub_district_code  total_hhd_having_piped_water_connection  \
# 0                2755                                   1861.0
# 1                2756                                   1864.0
# 2                2757                                   1612.0
# 3                2758                                     83.0
# 4                2759                                   2004.0
# ..                ...                                      ...
# 469              3226                                   1036.0
# 470              3227                                   2310.0
# 471              3228                                   2033.0
# 472              3229                                   2797.0
# 473              3230                                   1127.0
#
#      urban_hhd_pipe  sd_piped_hhds     total_hhd  sd_piped_hhds_pct
# 0          0.000000    1861.000000  23627.000000           7.876582
# 1          0.000000    1864.000000  31699.000000           5.880312
# 2        664.953565    2276.953565  20700.205901          10.999666
# 3         13.040272      96.040272   8845.622380           1.085738
# 4          0.000000    2004.000000  21890.000000           9.154865
# ..              ...            ...           ...                ...
# 469      169.500743    1205.500743  15484.969262           7.784973
# 470       96.550048    2406.550048  31751.483437           7.579331
# 471       30.603062    2063.603062   7062.390616          29.219611
# 472       44.070615    2841.070615  14248.294260          19.939724
# 473        0.000000    1127.000000   9344.000000          12.061216
#
# [474 rows x 6 columns]

# %% [markdown]
# ## total_hhd_not_having_sanitary_latrines

# %%
nosanitation_df = vul_df.copy()

# %%
nosanitation_df = nosanitation_df.groupby('sub_district_code')[['total_hhd_not_having_sanitary_latrines']].sum().reset_index()

# %%
nosanitation_df = nosanitation_df.merge(urban_hhd[['sub_district_code','urban_no_sanitation']], on='sub_district_code', how='outer')

# %%
nosanitation_df = nosanitation_df.fillna(0)

# %%
nosanitation_df['sd_nosanitation_hhds'] = nosanitation_df['urban_no_sanitation'] + nosanitation_df['total_hhd_not_having_sanitary_latrines']

# %%
nosanitation_df = nosanitation_df.merge(total_hhd[['sub_district_code','total_hhd']], on='sub_district_code')

# %%
nosanitation_df['sd_nosanitation_hhds_pct'] = 100*nosanitation_df['sd_nosanitation_hhds']/nosanitation_df['total_hhd']

# %%
nosanitation_df
# Out:
#     sub_district_code  total_hhd_not_having_sanitary_latrines  \
# 0                2755                                  5310.0
# 1                2756                                  8683.0
# 2                2757                                  2228.0
# 3                2758                                  1267.0
# 4                2759                                  1690.0
# ..                ...                                     ...
# 469              3226                                  3200.0
# 470              3227                                  2959.0
# 471              3228                                   299.0
# 472              3229                                  1918.0
# 473              3230                                  2094.0
#
#      urban_no_sanitation  sd_nosanitation_hhds     total_hhd  \
# 0               0.000000           5310.000000  23627.000000
# 1               0.000000           8683.000000  31699.000000
# 2             223.662972           2451.662972  20700.205901
# 3               4.386210           1271.386210   8845.622380
# 4               0.000000           1690.000000  21890.000000
# ..                   ...                   ...           ...
# 469            57.013064           3257.013064  15484.969262
# 470            32.475457           2991.475457  31751.483437
# 471            10.293609            309.293609   7062.390616
# 472            14.823538           1932.823538  14248.294260
# 473             0.000000           2094.000000   9344.000000
#
#      sd_nosanitation_hhds_pct
# 0                   22.474288
# 1                   27.392031
# 2                   11.843665
# 3                   14.373055
# 4                    7.720420
# ..                        ...
# 469                 21.033384
# 470                  9.421530
# 471                  4.379446
# 472                 13.565298
# 473                 22.410103
#
# [474 rows x 6 columns]

# %% [markdown]
# # ANTYODAYA MASTER

# %%
antyodaya_master_df = net_sown_area_in_hac_sd.reset_index()

# %%
antyodaya_master_df = antyodaya_master_df.merge(sd_electricity[['sub_district_code', 'avg_electricity']], how='outer')

# %%
antyodaya_master_df = antyodaya_master_df.merge(sd_tele[['sub_district_code', 'avg_tele']])

# %%
antyodaya_master_df = antyodaya_master_df.merge(pipe_df[['sub_district_code', 'sd_piped_hhds_pct']])

# %%
antyodaya_master_df = antyodaya_master_df.merge(nosanitation_df[['sub_district_code','sd_nosanitation_hhds_pct']])

# %%
antyodaya_master_df
# Out:
#     sub_district_code  net_sown_area_in_hac  avg_electricity  avg_tele  \
# 0                2755             20637.310         8.611694       2.0
# 1                2756             24144.640         9.705984       2.0
# 2                2757             14361.820        11.607692       3.0
# 3                2758              8136.000        11.177783       3.0
# 4                2759             11586.370         9.492645       3.0
# ..                ...                   ...              ...       ...
# 469              3226              9017.210        11.618324       3.0
# 470              3227              7170.903         9.128634       3.0
# 471              3228              7906.389        10.172096       3.0
# 472              3229              5896.254        10.412326       2.0
# 473              3230              7852.980        11.415240       2.0
#
#      sd_piped_hhds_pct  sd_nosanitation_hhds_pct
# 0             7.876582                 22.474288
# 1             5.880312                 27.392031
# 2            10.999666                 11.843665
# 3             1.085738                 14.373055
# 4             9.154865                  7.720420
# ..                 ...                       ...
# 469           7.784973                 21.033384
# 470           7.579331                  9.421530
# 471          29.219611                  4.379446
# 472          19.939724                 13.565298
# 473          12.061216                 22.410103
#
# [474 rows x 6 columns]

# %%
gdf_polygons
# Out:
#      OBJECTID stcode11 dtcode11 sdtcode11   Shape_Length    Shape_Area  \
# 0        2773       21      370     02755  175809.421683  6.516630e+08
# 1        2774       21      370     02756  192057.189614  7.626096e+08
# 2        2775       21      370     02757  133403.031651  3.456675e+08
# 3        2776       21      370     02758  113949.812620  2.672039e+08
# 4        2777       21      370     02759  135841.048349  3.752092e+08
# ..        ...      ...      ...       ...            ...           ...
# 473      3246       21      399     03226  149569.992418  5.100200e+08
# 474      3247       21      399     03227  269711.225643  9.885963e+08
# 475      3248       21      399     03228  129218.450510  4.291734e+08
# 476      3249       21      399     03229  130042.312962  3.676498e+08
# 477      3250       21      399     03230  130653.122822  4.129349e+08
#
#      stname      dtname     sdtname  Subdt_LGD  Dist_LGD  State_LGD  \
# 0    ODISHA     Bargarh    Paikamal       2755       347         21
# 1    ODISHA     Bargarh  Jharbandha       2756       347         21
# 2    ODISHA     Bargarh    Padmapur       2757       347         21
# 3    ODISHA     Bargarh  BurdenP.S.       2758       347         21
# 4    ODISHA     Bargarh    Gaisilet       2759       347         21
# ..      ...         ...         ...        ...       ...        ...
# 473  ODISHA  Malkangiri       Orkel       3226       364         21
# 474  ODISHA  Malkangiri    Kalimela       3227       364         21
# 475  ODISHA  Malkangiri       Podia       3228       364         21
# 476  ODISHA  Malkangiri     M.V. 79       3229       364         21
# 477  ODISHA  Malkangiri        Motu       3230       364         21
#
#                                               geometry
# 0    POLYGON ((82.90633 21.04445, 82.90599 21.04534...
# 1    POLYGON ((82.96518 21.19248, 82.96504 21.19318...
# 2    POLYGON ((83.16820 21.13856, 83.16775 21.13887...
# 3    POLYGON ((83.12346 20.98452, 83.12192 20.98650...
# 4    POLYGON ((83.28376 21.04885, 83.28268 21.04889...
# ..                                                 ...
# 473  POLYGON ((82.16914 18.48265, 82.16793 18.48307...
# 474  POLYGON ((81.72320 18.29129, 81.72195 18.29135...
# 475  POLYGON ((81.66331 18.32195, 81.66271 18.32223...
# 476  POLYGON ((81.64158 18.10071, 81.64075 18.10174...
# 477  POLYGON ((81.65802 18.00632, 81.65699 18.00799...
#
# [478 rows x 13 columns]

# %%
antyodaya_master_df.head()
# Out:
#   sub_district_code  net_sown_area_in_hac  avg_electricity  avg_tele  \
# 0              2755              20637.31         8.611694       2.0
# 1              2756              24144.64         9.705984       2.0
# 2              2757              14361.82        11.607692       3.0
# 3              2758               8136.00        11.177783       3.0
# 4              2759              11586.37         9.492645       3.0
#
#    sd_piped_hhds_pct  sd_nosanitation_hhds_pct
# 0           7.876582                 22.474288
# 1           5.880312                 27.392031
# 2          10.999666                 11.843665
# 3           1.085738                 14.373055
# 4           9.154865                  7.720420

# %%
#gdf_polygons = gdf_polygons.rename(columns = {'SDTCODE11':'sub_district_code'}, inplace = True)
antyodaya_master_df = pd.merge(gdf_polygons_renamed,antyodaya_master_df,on='sub_district_code', how='outer')

# %%
antyodaya_master_df[antyodaya_master_df.avg_electricity.isnull()]
# Out:
#      OBJECTID stcode11 dtcode11 sub_district_code  Shape_Length    Shape_Area  \
# 78       2851       21      374              2833  33838.394681  5.077331e+07
# 286      3059       21      386              3040  18439.369099  1.011031e+07
#
#      stname      dtname             sdtname  Subdt_LGD  Dist_LGD  State_LGD  \
# 78   ODISHA  Sundargarh  Raurkela (ITS)P.S.       2833       373         21
# 286  ODISHA     Khordha         Saheednagar       3040       362         21
#
#                                               geometry  net_sown_area_in_hac  \
# 78   POLYGON ((84.83204 22.27475, 84.82838 22.27520...                   NaN
# 286  POLYGON ((85.88455 20.28658, 85.88333 20.28763...                   NaN
#
#      avg_electricity  avg_tele  sd_piped_hhds_pct  sd_nosanitation_hhds_pct
# 78               NaN       NaN                NaN                       NaN
# 286              NaN       NaN                NaN                       NaN

# %%
antyodaya_master_df = antyodaya_master_df.merge(total_hhd[['sub_district_code', 'total_hhd']], on='sub_district_code')
antyodaya_master_df['total_hhd'] = antyodaya_master_df['total_hhd'].apply(lambda x: round(x,0))

# %%
antyodaya_master_df = antyodaya_master_df.drop(['OBJECTID','stcode11','dtcode11','Shape_Length','Shape_Area','stname','Subdt_LGD','Dist_LGD','State_LGD','geometry'],axis=1)

# %%
antyodaya_master_df.to_csv(r'D:\CivicDataLabs_IDS-DRR\IDS-DRR_Github\flood-data-ecosystem-Odisha\Sources\ANTYODAYA\data\antyodaya_variables.csv', index=False)

# %%
#original code for reference
'''antyodaya_master_df.drop(['geometry',
                           'district_1', 'revenue_cr', 'HQ', 'area', 
                           'are_new'],axis=1).to_csv('/home/krishna/IDS-DRR-Data-Pipeline/Sources/ANTYODAYA/data/variables/antyodaya/antyodaya_variables.csv', index=False)
'''
# Out:
# "antyodaya_master_df.drop(['geometry',\n                           'district_1', 'revenue_cr', 'HQ', 'area', \n                           'are_new'],axis=1).to_csv('/home/krishna/IDS-DRR-Data-Pipeline/Sources/ANTYODAYA/data/variables/antyodaya/antyodaya_variables.csv', index=False)\n"

# %%
antyodaya_master_df
# Out:
#     sub_district_code      dtname     sdtname  net_sown_area_in_hac  \
# 0                2755     Bargarh    Paikamal             20637.310
# 1                2756     Bargarh  Jharbandha             24144.640
# 2                2757     Bargarh    Padmapur             14361.820
# 3                2758     Bargarh  BurdenP.S.              8136.000
# 4                2759     Bargarh    Gaisilet             11586.370
# ..                ...         ...         ...                   ...
# 471              3226  Malkangiri       Orkel              9017.210
# 472              3227  Malkangiri    Kalimela              7170.903
# 473              3228  Malkangiri       Podia              7906.389
# 474              3229  Malkangiri     M.V. 79              5896.254
# 475              3230  Malkangiri        Motu              7852.980
#
#      avg_electricity  avg_tele  sd_piped_hhds_pct  sd_nosanitation_hhds_pct  \
# 0           8.611694       2.0           7.876582                 22.474288
# 1           9.705984       2.0           5.880312                 27.392031
# 2          11.607692       3.0          10.999666                 11.843665
# 3          11.177783       3.0           1.085738                 14.373055
# 4           9.492645       3.0           9.154865                  7.720420
# ..               ...       ...                ...                       ...
# 471        11.618324       3.0           7.784973                 21.033384
# 472         9.128634       3.0           7.579331                  9.421530
# 473        10.172096       3.0          29.219611                  4.379446
# 474        10.412326       2.0          19.939724                 13.565298
# 475        11.415240       2.0          12.061216                 22.410103
#
#      total_hhd
# 0      23627.0
# 1      31699.0
# 2      20700.0
# 3       8846.0
# 4      21890.0
# ..         ...
# 471    15485.0
# 472    31751.0
# 473     7062.0
# 474    14248.0
# 475     9344.0
#
# [476 rows x 9 columns]
