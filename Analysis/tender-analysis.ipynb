# %%
import pandas as pd
import os
import glob

# %%
od_tenders = pd.read_csv(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-Odisha\Sources\TENDERS\data\odisha_all_tenders.csv')

# %%
od_tenders = od_tenders.loc[od_tenders['Status'] == 'Accepted-AOC']
print(f"Number of accepted tenders: {len(od_tenders)}")
od_tenders
# Out:
# Number of accepted tenders: 4605
#                  Tender ID             tender_externalreference  \
# 2       2020_BPUTW_62754_1            TEQIP-III/2020/OD/bpuo/58
# 14        2020_OMC_59608_1                 NIT-5/OMC/Civil/2020
# 23      2018_CERWI_48091_2     Building Tender Online RWCSBP-45
# 25      2019_CERWI_53180_2          ONLINE-13-2018-19 (BRIDGES)
# 27      2020_CCEBA_59020_1  EE CKD NCB/05 /ORDRIPW-05 / 2019-20
# ...                    ...                                  ...
# 18284  2019_ORULB_56493_12                       BBLM-3/2019-20
# 18286   2023_DZPBR_85370_1  IFB-CDO-cum-EO,ZP,BGH,02 of 2022-23
# 18289   2023_DZPBR_85370_2  IFB-CDO-cum-EO,ZP,BGH,02 of 2022-23
# 18290   2023_DZPBR_85370_5  IFB-CDO-cum-EO,ZP,BGH,02 of 2022-23
# 18293   2023_DZPBR_85370_9  IFB-CDO-cum-EO,ZP,BGH,02 of 2022-23
#
#                                             tender_title  \
# 2                                        2x1 KW solar PV
# ...

# %%
od_tenders['Awarded Value'].str.replace(',','').astype(float).sum()
# Out:
# 70215901111.909
